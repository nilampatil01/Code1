# %% [markdown]
# <a href="https://colab.research.google.com/github/nilampatil01/Code1/blob/main/Untitled4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
x=10
if x>5:
  if x<10:
    print("A")
  else:
    print("B")
  else:
    print("c")
# Out:
#   File "/tmp/ipykernel_865/443619435.py", line 7
#     else:
#     ^
# SyntaxError: invalid syntax

# %%
x=10
if x>5:
    print("A")
if x>8:
   print("B")
else:
    print("c")
# Out:
# A
# B

# %%
num=5
for i in range(1,11):
  print(num*i);
# Out:
# 5
# 10
# 15
# 20
# 25
# 30
# 35
# 40
# 45
# 50

# %%
name = ["sushat","rohita","nilam"]
for i in name:
  print(i)
# Out:
# sushat
# rohita
# nilam
