# %% [markdown]
# <a href="https://colab.research.google.com/github/nilampatil01/Code1/blob/main/if.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
num=int(input("Enter the number"))
if num>0:
  print("the no is positive");
# Out:
# Enter the number8
# the no is positive

# %%
num=int(input("Enter the number"))
if num<0:
  print("the no is negative");
# Out:
# Enter the number-5
# the no is negative

# %%
i=int(input("Enter the number"))
if i== 0:
  print("the no is zero")
# Out:
# Enter the number0
# the no is zero

# %%
i=int(input("Enter the number"))
if i>10:
  print("the number is greater than 10")
# Out:
# Enter the number55
# the number is greater than 10

# %%
i=int(input("Enter the number"))
if i<10:
  print("the number is less then 10")
# Out:
# Enter the number5
# the number is less then 10

# %%
age=int(input("Enter the age"))
if age>=18:
        print("the person age is 18 or above");
# Out:
# Enter the age18
# the person age is 18 or above

# %%
i=int(input("Enter the number"))
if i==100:
  print("the number is equal to 100")
# Out:
# Enter the number100
# the number is equal to 100

# %%
i=int(input("Enter the number"))
if i !=50:
  print("the is not equal to 50")
# Out:
# Enter the number45
# the is not equal to 50

# %%
stu=int(input("Enter the marks"))
if stu>=40:
  print("student passed when marks are greater than or equal to 40")
# Out:
# Enter the marks54
# student passed when marks are greater than or equal to 40

# %%
temp=int(input("Enter the temp"))
if temp>30:
  print ("the temp is greater than 30")
# Out:
# Enter the temp60
# the temp is greater than 30

# %%
height=int(input("Enter the height"))
if height>5:
  print("Person's height is greater than 5 feet");
# Out:
# Enter the height10
# Person's height is greater than 5 feet

# %%
i=int(input("Enter the number"))
if i%5==0:
  print("if a number is divisible by 5");
# Out:
# Enter the number20
# if a number is divisible by 5

# %%
i=int(input("Enter the number"))
if i%10==0:
  print("if number is divisible by 10");
# Out:
# Enter the number50
# if number is divisible by 10

# %%
i=int(input("Enter the number"))
if i%2==0:
  print("The number is even");
# Out:
# Enter the number4
# The number is even

# %%
i=int(input("Enter the number"))
if i%2 !=0:
  print("The number is odd")
# Out:
# Enter the number5
# The number is odd

# %%
i=str(input("Enter the character"))
if i == ("A"):
  print("If a charecter is A");
# Out:
# Enter the characterA
# If a charecter is A

# %%
passward=input("Enter passswaard:")
if passward == "1234":
  print("correct passward");
# Out:
# Enter passswaard:1234
# correct passward

# %%
i=int(input("Enter the age"))
if i==18:
  print("the person age is exactly 18")
# Out:
# Enter the age18
# the person age is exactly 18

# %%
i=int(input("Enter the number"))
if i>50:
  print("the is greater than 50");
# Out:
# Enter the number55
# the is greater than 50

# %%
i=int(input("Enter the number:"))
if i>=1 and i<=100:
  print("number is between 1 and 100");
# Out:
# Enter the number:45
# number is between 1 and 100
